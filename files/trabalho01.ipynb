# %% [markdown]
# # SME0829 - Aprendizado de Máquina
# ## Trabalho 01 - Regressão Linear
#
# ***
# Bryan
#
# Francisco Miranda
#
# Heitor Carvalho Pinheiro - 11833351
#
# Victor
#
# Yuki
#
# ***

# %% [markdown]
# ### Índice
# 1. [Introdução](#1)
# 2. [Conjunto de Dados](#2)
# 3. [Análise](#3)
# 4. [Modelo de ML](#4)
# 5. [Conclusão](#5)

# %% [markdown]
# ## Introdução <a class= "anchor" id="1" ></a>

# %% [markdown]
# ## Conjunto de dados <a class= "anchor" id="2" ></a>

# %% [markdown]
# ## Análise <a class= "anchor" id="3" ></a>

# %% [markdown]
# ## Modelo de ML <a class= "anchor" id="4" ></a>

# %% [markdown]
# ## Conclusão <a class= "anchor" id="5" ></a>
